# %%
#tuples
languages = ('python','c','java')
print(languages[1])
languages[1] = 'html'
print(languages)
# Out:
# c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 languages = ('python','c','java')
#       3 print(languages[1])
# ----> 4 languages[1] = 'html'
#       5 print(languages)
#
# TypeError: 'tuple' object does not support item assignment

# %%
marks =[7,5,4,3,2]
print(marks[-2])
print(marks[7])
# Out:
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 marks =[7,5,4,3,2]
#       2 print(marks[-2])
# ----> 3 print(marks[7])
#
# IndexError: list index out of range
